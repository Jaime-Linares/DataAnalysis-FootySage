# %% [markdown]
# ## Entrenamiento de modelos y evaluación de modelos

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "La Liga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/La Liga(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.400000                    0.153846
# 1                     0.312500                    0.300000
# 2                     0.333333                    0.400000
# 3                     0.461538                    0.400000
# 4                     0.153846                    0.200000
# 5                     0.000000                    0.296296
# 6                     0.250000                    0.000000
# 7                     0.181818                    0.428571
# 8                     0.272727                    0.500000
# 9                     0.375000                    0.400000
# 10                    0.777778                    0.111111
#
#     average_shots_on_target_distance_home  \
# 0                               20.462904
# 1                               25.239973
# 2                               33.431447
# 3                               24.394269
# 4                               20.432657
# 5                              120.000000
# 6                               25.685715
# 7                               24.736200
# 8                               22.581797
# 9                               33.762858
# 10                              13.798140
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               15.923442                      0.600000
# 1                               18.652679                      0.187500
# 2                               11.773407                      0.500000
# 3                                9.439840                      0.538462
# 4                               19.849825                      0.384615
# 5                               21.352619                      0.666667
# 6                              120.000000                      0.416667
# 7                               17.236907                      0.272727
# 8                               18.761077                      0.454545
# 9                               12.528144                      0.125000
# 10                              22.016812                      1.000000
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.384615                 0.630915
# 1                       0.600000                 0.759191
# 2                       0.700000                 0.609065
# 3                       0.800000                 0.760377
# 4                       0.800000                 0.775176
# 5                       0.444444                 0.624642
# 6                       0.571429                 0.814540
# 7                       0.500000                 0.649518
# 8                       0.875000                 0.735849
# 9                       0.700000                 0.757895
# 10                      0.333333                 0.652278
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.804089                  0.000000
# 1                  0.690647                  0.285714
# 2                  0.809783                  0.125000
# 3                  0.676543                  0.125000
# 4                  0.700581                  0.416667
# 5                  0.832378                  0.125000
# 6                  0.757075                  0.250000
# 7                  0.864215                  0.230769
# 8                  0.623574                  0.312500
# 9                  0.686076                  0.166667
# 10                 0.759850                  0.000000
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.000000  ...                              0.500000
# 1                   0.263158  ...                              0.666667
# 2                   0.222222  ...                              0.166667
# 3                   0.285714  ...                              0.500000
# 4                   0.272727  ...                              0.500000
# 5                   0.250000  ...                              0.400000
# 6                   1.000000  ...                              0.500000
# 7                   0.437500  ...                              0.333333
# 8                   0.375000  ...                              0.500000
# 9                   0.222222  ...                              0.500000
# 10                  0.214286  ...                              1.000000
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           1.000000
# 1                                           0.000000
# 2                                           0.250000
# 3                                           0.666667
# 4                                           0.000000
# 5                                           0.500000
# 6                                           0.500000
# 7                                           0.500000
# 8                                           0.500000
# 9                                           0.333333
# 10                                          1.000000
#
#     percentage_passes_under_pressure_home  \
# 0                                0.364780
# 1                                0.476190
# 2                                0.196491
# 3                                0.582857
# 4                                0.555556
# 5                                0.314516
# 6                                0.487500
# 7                                0.269565
# 8                                0.608000
# 9                                0.555556
# 10                               0.566372
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.000000
# 1                                            0.333333
# 2                                            0.400000
# 3                                            1.000000
# 4                                            0.750000
# 5                                            0.200000
# 6                                            1.000000
# 7                                            0.142857
# 8                                            0.666667
# 9                                            0.500000
# 10                                           0.000000
#
#     percentage_set_piece_shots_home  \
# 0                          0.214286
# 1                          0.470588
# 2                          0.333333
# 3                          0.600000
# 4                          0.615385
# 5                          0.200000
# 6                          0.533333
# 7                          0.642857
# 8                          0.818182
# 9                          0.428571
# 10                         0.538462
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.285714
# 1                                      0.000000
# 2                                      0.250000
# 3                                      0.444444
# 4                                      0.384615
# 5                                      0.250000
# 6                                      0.333333
# 7                                      0.400000
# 8                                      0.692308
# 9                                      0.166667
# 10                                     0.777778
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                    0.40
# 1                             0.5                                    0.50
# 2                             0.5                                    0.75
# 3                             0.5                                    0.60
# 4                             0.5                                    0.50
# 5                             0.5                                    0.50
# 6                             0.5                                    0.60
# 7                             0.5                                    0.60
# 8                             0.5                                    0.50
# 9                             0.4                                    0.40
# 10                            0.5                                    0.50
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           1.000000                           0.500000
# 1                           1.000000                           1.000000
# 2                           0.666667                           0.500000
# 3                           0.500000                           0.500000
# 4                           0.600000                           0.500000
# 5                           0.333333                           0.500000
# 6                           0.666667                           0.666667
# 7                           0.000000                           0.500000
# 8                           0.000000                           0.500000
# 9                           0.666667                           0.500000
# 10                          0.000000                           0.500000
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 20}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        21
#            1       0.67      0.56      0.61        18
#            2       0.72      0.78      0.75        37
#
#     accuracy                           0.70        76
#    macro avg       0.69      0.67      0.68        76
# weighted avg       0.70      0.70      0.69        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 125}
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        21
#            1       0.57      0.44      0.50        18
#            2       0.75      0.81      0.78        37
#
#     accuracy                           0.68        76
#    macro avg       0.65      0.64      0.64        76
# weighted avg       0.68      0.68      0.68        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'n_estimators': 15}
#               precision    recall  f1-score   support
#
#            0       0.58      0.67      0.62        21
#            1       0.67      0.44      0.53        18
#            2       0.78      0.84      0.81        37
#
#     accuracy                           0.70        76
#    macro avg       0.67      0.65      0.65        76
# weighted avg       0.70      0.70      0.69        76
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': None}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.46      0.57      0.51        21
#            1       0.40      0.22      0.29        18
#            2       0.65      0.70      0.68        37
#
#     accuracy                           0.55        76
#    macro avg       0.50      0.50      0.49        76
# weighted avg       0.54      0.55      0.54        76
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': None}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.50      0.38      0.43        21
#            1       0.31      0.50      0.38        18
#            2       0.81      0.68      0.74        37
#
#     accuracy                           0.55        76
#    macro avg       0.54      0.52      0.52        76
# weighted avg       0.60      0.55      0.57        76
#
# Decision Tree Selected Features
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53        21
#            1       0.45      0.28      0.34        18
#            2       0.63      0.70      0.67        37
#
#     accuracy                           0.57        76
#    macro avg       0.53      0.52      0.51        76
# weighted avg       0.55      0.57      0.55        76
#
# Logistic Regression
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Best hyperparameters: {'C': 0.1, 'l1_ratio': 0.2, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.68      0.62      0.65        21
#            1       0.38      0.44      0.41        18
#            2       0.81      0.78      0.79        37
#
#     accuracy                           0.66        76
#    macro avg       0.62      0.62      0.62        76
# weighted avg       0.67      0.66      0.66        76
#
# Logistic Regression Selected Features
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Best hyperparameters: {'C': 1, 'l1_ratio': 0.3, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        21
#            1       0.59      0.56      0.57        18
#            2       0.81      0.81      0.81        37
#
#     accuracy                           0.71        76
#    macro avg       0.68      0.68      0.68        76
# weighted avg       0.71      0.71      0.71        76
#
# KNN
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.52      0.52      0.52        21
#            1       0.25      0.17      0.20        18
#            2       0.72      0.84      0.78        37
#
#     accuracy                           0.59        76
#    macro avg       0.50      0.51      0.50        76
# weighted avg       0.55      0.59      0.57        76
#
# KNN Selected Features
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.56      0.43      0.49        21
#            1       0.46      0.33      0.39        18
#            2       0.68      0.86      0.76        37
#
#     accuracy                           0.62        76
#    macro avg       0.57      0.54      0.55        76
# weighted avg       0.60      0.62      0.60        76
#
# Experiment finished.
#                              Train Accuracy  Test Accuracy  Precision Macro  \
# Random Forest                      0.881579       0.697368         0.686111
# Random Forest Oversampling         0.995434       0.684211         0.652597
# Random Forest Reduced              0.947368       0.697368         0.675000
# Decision Tree                      0.822368       0.552632         0.503846
# Decision Tree Oversampling         0.885845       0.552632         0.538932
# Decision Tree Reduced              0.651316       0.565789         0.529564
# Logistic Regression                0.809211       0.657895         0.623573
# Logistic Regression Reduced        0.726974       0.710526         0.678470
# KNN                                0.625000       0.592105         0.498247
# KNN Reduced                        1.000000       0.618421         0.568297
#
#                              Precision Weighted  Recall Macro  \
# Random Forest                          0.695066      0.668669
# Random Forest Oversampling             0.676307      0.640641
# Random Forest Reduced                  0.696382      0.649650
# Decision Tree                          0.538715      0.498784
# Decision Tree Oversampling             0.604275      0.518876
# Decision Tree Reduced                  0.554543      0.517303
# Logistic Regression                    0.671462      0.615759
# Logistic Regression Reduced            0.709893      0.677678
# KNN                                    0.554927      0.509438
# KNN Reduced                            0.596206      0.542257
#
#                              Recall Weighted  F1 Macro  F1 Weighted  \
# Random Forest                       0.697368  0.675325     0.694463
# Random Forest Oversampling          0.684211  0.643461     0.677705
# Random Forest Reduced               0.697368  0.653583     0.690248
# Decision Tree                       0.552632  0.490559     0.537543
# Decision Tree Oversampling          0.552632  0.516902     0.568166
# Decision Tree Reduced               0.565789  0.514943     0.553600
# Logistic Regression                 0.657895  0.618259     0.663577
# Logistic Regression Reduced         0.710526  0.677801     0.710002
# KNN                                 0.592105  0.499603     0.569408
# KNN Reduced                         0.618421  0.545163     0.597032
#
#                                                         Hyperparameters chosen
# Random Forest                {'criterion': 'entropy', 'max_depth': 4, 'max_...
# Random Forest Oversampling   {'criterion': 'gini', 'max_depth': 6, 'max_fea...
# Random Forest Reduced        {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Decision Tree                {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Decision Tree Oversampling   {'criterion': 'gini', 'max_depth': 6, 'max_fea...
# Decision Tree Reduced        {'criterion': 'gini', 'max_depth': 2, 'max_fea...
# Logistic Regression          {'C': 0.1, 'l1_ratio': 0.2, 'penalty': 'elasti...
# Logistic Regression Reduced  {'C': 1, 'l1_ratio': 0.3, 'penalty': 'elasticn...
# KNN                          {'metric': 'manhattan', 'n_neighbors': 20, 'we...
# KNN Reduced                  {'metric': 'manhattan', 'n_neighbors': 11, 'we...
