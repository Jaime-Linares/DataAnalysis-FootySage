# %% [markdown]
# ## Entrenamiento de modelos y evaluación de modelos

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "La Liga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/La Liga(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.400000                    0.153846
# 1                     0.312500                    0.300000
# 2                     0.333333                    0.400000
# 3                     0.461538                    0.400000
# 4                     0.153846                    0.200000
# 5                     0.000000                    0.296296
# 6                     0.250000                    0.000000
# 7                     0.181818                    0.428571
# 8                     0.272727                    0.500000
# 9                     0.375000                    0.400000
# 10                    0.777778                    0.111111
#
#     average_shots_on_target_distance_home  \
# 0                               20.462904
# 1                               25.239973
# 2                               33.431447
# 3                               24.394269
# 4                               20.432657
# 5                              120.000000
# 6                               25.685715
# 7                               24.736200
# 8                               22.581797
# 9                               33.762858
# 10                              13.798140
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               15.923442                      0.600000
# 1                               18.652679                      0.187500
# 2                               11.773407                      0.500000
# 3                                9.439840                      0.538462
# 4                               19.849825                      0.384615
# 5                               21.352619                      0.666667
# 6                              120.000000                      0.416667
# 7                               17.236907                      0.272727
# 8                               18.761077                      0.454545
# 9                               12.528144                      0.125000
# 10                              22.016812                      1.000000
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.384615                 0.630915
# 1                       0.600000                 0.759191
# 2                       0.700000                 0.609065
# 3                       0.800000                 0.760377
# 4                       0.800000                 0.775176
# 5                       0.444444                 0.624642
# 6                       0.571429                 0.814540
# 7                       0.500000                 0.649518
# 8                       0.875000                 0.735849
# 9                       0.700000                 0.757895
# 10                      0.333333                 0.652278
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.804089                  0.000000
# 1                  0.690647                  0.285714
# 2                  0.809783                  0.125000
# 3                  0.676543                  0.125000
# 4                  0.700581                  0.416667
# 5                  0.832378                  0.125000
# 6                  0.757075                  0.250000
# 7                  0.864215                  0.230769
# 8                  0.623574                  0.312500
# 9                  0.686076                  0.166667
# 10                 0.759850                  0.000000
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.000000  ...                              0.500000
# 1                   0.263158  ...                              0.666667
# 2                   0.222222  ...                              0.166667
# 3                   0.285714  ...                              0.500000
# 4                   0.272727  ...                              0.500000
# 5                   0.250000  ...                              0.400000
# 6                   1.000000  ...                              0.500000
# 7                   0.437500  ...                              0.333333
# 8                   0.375000  ...                              0.500000
# 9                   0.222222  ...                              0.500000
# 10                  0.214286  ...                              1.000000
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           1.000000
# 1                                           0.000000
# 2                                           0.250000
# 3                                           0.666667
# 4                                           0.000000
# 5                                           0.500000
# 6                                           0.500000
# 7                                           0.500000
# 8                                           0.500000
# 9                                           0.333333
# 10                                          1.000000
#
#     percentage_passes_under_pressure_home  \
# 0                                0.364780
# 1                                0.476190
# 2                                0.196491
# 3                                0.582857
# 4                                0.555556
# 5                                0.314516
# 6                                0.487500
# 7                                0.269565
# 8                                0.608000
# 9                                0.555556
# 10                               0.566372
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.000000
# 1                                            0.333333
# 2                                            0.400000
# 3                                            1.000000
# 4                                            0.750000
# 5                                            0.200000
# 6                                            1.000000
# 7                                            0.142857
# 8                                            0.666667
# 9                                            0.500000
# 10                                           0.000000
#
#     percentage_set_piece_shots_home  \
# 0                          0.214286
# 1                          0.470588
# 2                          0.333333
# 3                          0.600000
# 4                          0.615385
# 5                          0.200000
# 6                          0.533333
# 7                          0.642857
# 8                          0.818182
# 9                          0.428571
# 10                         0.538462
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.285714
# 1                                      0.000000
# 2                                      0.250000
# 3                                      0.444444
# 4                                      0.384615
# 5                                      0.250000
# 6                                      0.333333
# 7                                      0.400000
# 8                                      0.692308
# 9                                      0.166667
# 10                                     0.777778
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                    0.40
# 1                             0.5                                    0.50
# 2                             0.5                                    0.75
# 3                             0.5                                    0.60
# 4                             0.5                                    0.50
# 5                             0.5                                    0.50
# 6                             0.5                                    0.60
# 7                             0.5                                    0.60
# 8                             0.5                                    0.50
# 9                             0.4                                    0.40
# 10                            0.5                                    0.50
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           1.000000                           0.500000
# 1                           1.000000                           1.000000
# 2                           0.666667                           0.500000
# 3                           0.500000                           0.500000
# 4                           0.600000                           0.500000
# 5                           0.333333                           0.500000
# 6                           0.666667                           0.666667
# 7                           0.000000                           0.500000
# 8                           0.000000                           0.500000
# 9                           0.666667                           0.500000
# 10                          0.000000                           0.500000
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best hyperparameters: {'classifier__max_depth': 8, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46        21
#            1       0.33      0.11      0.17        18
#            2       0.62      0.86      0.72        37
#
#     accuracy                           0.57        76
#    macro avg       0.48      0.47      0.45        76
# weighted avg       0.52      0.57      0.52        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best hyperparameters: {'classifier__max_depth': 8, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62        21
#            1       0.50      0.11      0.18        18
#            2       0.63      0.92      0.75        37
#
#     accuracy                           0.63        76
#    macro avg       0.60      0.53      0.51        76
# weighted avg       0.61      0.63      0.58        76
#
# Decision Tree
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# Best hyperparameters: {'classifier__max_depth': 4, 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 8}
#               precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51        21
#            1       0.38      0.17      0.23        18
#            2       0.59      0.73      0.65        37
#
#     accuracy                           0.54        76
#    macro avg       0.49      0.47      0.46        76
# weighted avg       0.51      0.54      0.51        76
#
# Decision Tree Selected Features
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# Best hyperparameters: {'classifier__max_depth': 4, 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 2}
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50        21
#            1       0.43      0.17      0.24        18
#            2       0.59      0.73      0.65        37
#
#     accuracy                           0.54        76
#    macro avg       0.50      0.47      0.46        76
# weighted avg       0.52      0.54      0.51        76
#
# Logistic Regression
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.62      0.59        21
#            1       0.21      0.17      0.19        18
#            2       0.77      0.81      0.79        37
#
#     accuracy                           0.61        76
#    macro avg       0.52      0.53      0.52        76
# weighted avg       0.58      0.61      0.59        76
#
# Logistic Regression Selected Features
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.62      0.59        21
#            1       0.21      0.17      0.19        18
#            2       0.77      0.81      0.79        37
#
#     accuracy                           0.61        76
#    macro avg       0.52      0.53      0.52        76
# weighted avg       0.58      0.61      0.59        76
#
# KNN
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best hyperparameters: {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'uniform'}
#               precision    recall  f1-score   support
#
#            0       0.53      0.48      0.50        21
#            1       0.35      0.33      0.34        18
#            2       0.70      0.76      0.73        37
#
#     accuracy                           0.58        76
#    macro avg       0.53      0.52      0.52        76
# weighted avg       0.57      0.58      0.57        76
#
# KNN Selected Features
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best hyperparameters: {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'}
# Train Accuracy (Reduced): 1.0000
# Test Accuracy (Reduced): 0.5395
# Cross-Validation Accuracy (Reduced): 0.5791 +/- 0.0743
#               precision    recall  f1-score   support
#
#            0       0.60      0.43      0.50        21
#            1       0.21      0.17      0.19        18
#            2       0.62      0.78      0.69        37
#
#     accuracy                           0.54        76
#    macro avg       0.48      0.46      0.46        76
# weighted avg       0.52      0.54      0.52        76
#
# Experiment finished.
#              train_accuracy  test_accuracy  cv_scores_mean  cv_scores_std
# Model
# RF                 0.996711       0.565789        0.645027       0.051981
# RF_Reduced         0.996711       0.631579        0.625301       0.059369
# DT                 0.756579       0.539474        0.552678       0.038732
# DT_Reduced         0.759868       0.539474        0.601858       0.036296
# LR                 0.746711       0.605263        0.674536       0.054287
# LR_Reduced         0.750000       0.605263        0.674536       0.062566
# KNN                0.684211       0.578947        0.559180       0.081356
# KNN_Reduced        1.000000       0.539474        0.579126       0.074285
