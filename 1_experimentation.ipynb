# %% [markdown]
# ## Experimentación

# %% [markdown]
# En este cuaderno vamos a entrenar modelos con los datos de cada una de las competiciones y sacar conclusiones acerca de que modelos son mejor para cada competición según los resultados que obtengamos.

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "La Liga"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


competition_name = "La Liga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_LaLiga = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/La Liga(2015_2016_male)_reduced.csv

# %%
matches_in_LaLiga.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3825565                    0.400000                    0.153846
# 1    3825564                    0.312500                    0.300000
# 2     266236                    0.333333                    0.400000
# 3    3825570                    0.461538                    0.400000
# 4    3825562                    0.153846                    0.200000
# 5    3825567                    0.000000                    0.296296
# 6    3825563                    0.250000                    0.000000
# 7    3825569                    0.181818                    0.428571
# 8    3825568                    0.272727                    0.500000
# 9    3825566                    0.375000                    0.400000
# 10   3825578                    0.777778                    0.111111
#
#     average_shots_on_target_distance_home  \
# 0                               20.462904
# 1                               25.239973
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_LaLiga)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 34}
#               precision    recall  f1-score   support
#
#            0       0.60      0.71      0.65        21
#            1       0.75      0.17      0.27        18
#            2       0.70      0.89      0.79        37
#
#     accuracy                           0.67        76
#    macro avg       0.68      0.59      0.57        76
# weighted avg       0.69      0.67      0.63        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 48}
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68        21
#            1       0.56      0.50      0.53        18
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Logistic Regression tras hacerle una reducción de dimensionalidad a los datos de entrenamiento con ayuda de la información mutua (MI).

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "Premier League"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


competition_name = "Premier League"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_PremierLeague = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Premier League(2015_2016_male)_reduced.csv

# %%
matches_in_PremierLeague.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3754097                    0.111111                    0.555556
# 1    3754112                    0.300000                    0.285714
# 2    3754141                    0.260870                    0.500000
# 3    3754237                    0.421053                    0.555556
# 4    3754300                    0.454545                    0.454545
# 5    3754138                    0.352941                    0.636364
# 6    3754128                    0.166667                    0.428571
# 7    3753985                    0.166667                    0.375000
# 8    3754078                    0.400000                    0.625000
# 9    3754145                    0.222222                    0.350000
# 10   3754034                    0.235294                    0.454545
#
#     average_shots_on_target_distance_home  \
# 0                               15.620819
# 1                               10.397006
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_PremierLeague)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'n_estimators': 30}
#               precision    recall  f1-score   support
#
#            0       0.62      0.78      0.69        23
#            1       0.53      0.36      0.43        22
#            2       0.75      0.77      0.76        31
#
#     accuracy                           0.66        76
#    macro avg       0.63      0.64      0.63        76
# weighted avg       0.65      0.66      0.65        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# c:\Users\jaime\Desktop\TFG (FootySage)\FootySage\venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Logistic Regression tras hacerle una reducción de dimensionalidad a los datos de entrenamiento con ayuda de la información mutua (MI).

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "Serie A"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


competition_name = "Serie A"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_SerieA = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Serie A(2015_2016_male)_reduced.csv

# %%
matches_in_SerieA.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3878548                    0.285714                    0.285714
# 1    3878541                    0.583333                    0.285714
# 2    3878549                    0.250000                    0.250000
# 3    3878547                    0.230769                    0.230769
# 4    3878546                    0.352941                    0.266667
# 5    3878545                    0.700000                    0.280000
# 6    3878544                    0.315789                    0.300000
# 7    3878543                    0.363636                    0.000000
# 8    3878542                    0.500000                    0.000000
# 9    3878540                    0.409091                    0.444444
# 10   3878555                    0.388889                    0.200000
#
#     average_shots_on_target_distance_home  \
# 0                               16.182880
# 1                               16.798535
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_SerieA)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 41}
#               precision    recall  f1-score   support
#
#            0       0.62      0.68      0.65        22
#            1       0.36      0.21      0.27        19
#            2       0.63      0.74      0.68        35
#
#     accuracy                           0.59        76
#    macro avg       0.54      0.55      0.53        76
# weighted avg       0.56      0.59      0.57        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 58}
#               precision    recall  f1-score   support
#
#            0       0.69      0.50      0.58        22
#            1       0.24      0.21      0.22        19
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Logistic Regression tras hacerle una reducción de dimensionalidad a los datos de entrenamiento con ayuda de la información mutua (MI) o con el modelo Random Forest tras hacerle una reducción de dimensionalidad a los datos de entrenamiento con ayuda de la información mutua (MI).

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "Ligue 1"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


competition_name = "Ligue 1"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_Ligue1 = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Ligue 1(2015_2016_male)_reduced.csv

# %%
matches_in_Ligue1.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3829421                    0.333333                    0.166667
# 1    3829420                    0.307692                    0.428571
# 2    3829413                    0.166667                    0.333333
# 3    3829416                    0.333333                    0.352941
# 4    3829422                    0.227273                    0.500000
# 5    3829419                    0.363636                    0.312500
# 6    3829418                    0.400000                    0.400000
# 7    3829417                    0.307692                    0.142857
# 8    3829415                    0.272727                    0.500000
# 9    3829414                    0.222222                    0.500000
# 10   3829430                    0.312500                    0.285714
#
#     average_shots_on_target_distance_home  \
# 0                               25.129294
# 1                               20.107446
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_Ligue1)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 60}
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62        22
#            1       0.50      0.32      0.39        22
#            2       0.67      0.81      0.73        32
#
#     accuracy                           0.62        76
#    macro avg       0.59      0.59      0.58        76
# weighted avg       0.60      0.62      0.60        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 48}
#               precision    recall  f1-score   support
#
#            0       0.77      0.45      0.57        22
#            1       0.36      0.36      0.36        22
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Random Forest.

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "1. Bundesliga"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


competition_name = "1. Bundesliga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_5_major_leagues = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/1. Bundesliga(2015_2016_male)_reduced.csv

# %%
matches_in_5_major_leagues.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3890267                    0.375000                    0.461538
# 1    3890265                    0.150000                    0.272727
# 2    3890264                    0.133333                    0.312500
# 3    3890263                    0.272727                    0.357143
# 4    3890262                    0.272727                    0.357143
# 5    3890260                    0.360000                    0.333333
# 6    3890266                    0.285714                    0.500000
# 7    3890261                    0.437500                    0.200000
# 8    3890259                    0.409091                    0.200000
# 9    3890275                    0.666667                    0.444444
# 10   3890274                    0.555556                    0.400000
#
#     average_shots_on_target_distance_home  \
# 0                               16.622853
# 1                               20.255117
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_5_major_leagues)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'n_estimators': 11}
#               precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63        20
#            1       0.47      0.60      0.53        15
#            2       0.75      0.78      0.76        27
#
#     accuracy                           0.66        62
#    macro avg       0.65      0.64      0.64        62
# weighted avg       0.68      0.66      0.66        62
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 64}
#               precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49        20
#            1       0.25      0.20      0.22        15
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Random Forest.

# %% [markdown]
# ### Entrenamiento evaluación de modelos para "5 major leagues"

# %% [markdown]
# Comprobamos que tengamos los datos previamente y si es así, los cargamos en una variable.

# %%
import pandas as pd
import os


output_dir = "data/reduced/"
filename = "5_major_leagues.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_5_major_leagues = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/5_major_leagues.csv

# %%
matches_in_5_major_leagues.head(11)
# Out:
#     match_id  shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0    3890267                    0.375000                    0.461538
# 1    3890265                    0.150000                    0.272727
# 2    3890264                    0.133333                    0.312500
# 3    3890263                    0.272727                    0.357143
# 4    3890262                    0.272727                    0.357143
# 5    3890260                    0.360000                    0.333333
# 6    3890266                    0.285714                    0.500000
# 7    3890261                    0.437500                    0.200000
# 8    3890259                    0.409091                    0.200000
# 9    3890275                    0.666667                    0.444444
# 10   3890274                    0.555556                    0.400000
#
#     average_shots_on_target_distance_home  \
# 0                               16.622853
# 1                               20.255117
# ...

# %% [markdown]
# Una vez que tenemos los datos cargados en una variable, procedemos a entrenar los modelos y ver que resultados obtenemos de ellos.

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_5_major_leagues)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'n_estimators': 74}
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67       108
#            1       0.44      0.38      0.41        95
#            2       0.74      0.71      0.72       162
#
#     accuracy                           0.63       365
#    macro avg       0.60      0.61      0.60       365
# weighted avg       0.63      0.63      0.63       365
#
# Random Forest Oversampling
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 56}
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67       108
#            1       0.43      0.35      0.38        95
# ...

# %% [markdown]
# Una vez vistos los resultados, podemos afirmar que los mejores resultados, teniendo en cuenta la precisión sobre los datos de prueba, se obtienen con el modelo Logistic Regression tras hacerle una reducción de dimensionalidad a los datos de entrenamiento con ayuda del análisis de componente principales (PCA).
