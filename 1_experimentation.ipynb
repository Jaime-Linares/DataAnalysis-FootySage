# %% [markdown]
# ## Entrenamiento de modelos y evaluación de modelos

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "La Liga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/La Liga(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.400000                    0.153846
# 1                     0.312500                    0.300000
# 2                     0.333333                    0.400000
# 3                     0.461538                    0.400000
# 4                     0.153846                    0.200000
# 5                     0.000000                    0.296296
# 6                     0.250000                    0.000000
# 7                     0.181818                    0.428571
# 8                     0.272727                    0.500000
# 9                     0.375000                    0.400000
# 10                    0.777778                    0.111111
#
#     average_shots_on_target_distance_home  \
# 0                               20.462904
# 1                               25.239973
# 2                               33.431447
# 3                               24.394269
# 4                               20.432657
# 5                              120.000000
# 6                               25.685715
# 7                               24.736200
# 8                               22.581797
# 9                               33.762858
# 10                              13.798140
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               15.923442                      0.600000
# 1                               18.652679                      0.187500
# 2                               11.773407                      0.500000
# 3                                9.439840                      0.538462
# 4                               19.849825                      0.384615
# 5                               21.352619                      0.666667
# 6                              120.000000                      0.416667
# 7                               17.236907                      0.272727
# 8                               18.761077                      0.454545
# 9                               12.528144                      0.125000
# 10                              22.016812                      1.000000
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.384615                 0.630915
# 1                       0.600000                 0.759191
# 2                       0.700000                 0.609065
# 3                       0.800000                 0.760377
# 4                       0.800000                 0.775176
# 5                       0.444444                 0.624642
# 6                       0.571429                 0.814540
# 7                       0.500000                 0.649518
# 8                       0.875000                 0.735849
# 9                       0.700000                 0.757895
# 10                      0.333333                 0.652278
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.804089                  0.000000
# 1                  0.690647                  0.285714
# 2                  0.809783                  0.125000
# 3                  0.676543                  0.125000
# 4                  0.700581                  0.416667
# 5                  0.832378                  0.125000
# 6                  0.757075                  0.250000
# 7                  0.864215                  0.230769
# 8                  0.623574                  0.312500
# 9                  0.686076                  0.166667
# 10                 0.759850                  0.000000
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.000000  ...                              0.500000
# 1                   0.263158  ...                              0.666667
# 2                   0.222222  ...                              0.166667
# 3                   0.285714  ...                              0.500000
# 4                   0.272727  ...                              0.500000
# 5                   0.250000  ...                              0.400000
# 6                   1.000000  ...                              0.500000
# 7                   0.437500  ...                              0.333333
# 8                   0.375000  ...                              0.500000
# 9                   0.222222  ...                              0.500000
# 10                  0.214286  ...                              1.000000
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           1.000000
# 1                                           0.000000
# 2                                           0.250000
# 3                                           0.666667
# 4                                           0.000000
# 5                                           0.500000
# 6                                           0.500000
# 7                                           0.500000
# 8                                           0.500000
# 9                                           0.333333
# 10                                          1.000000
#
#     percentage_passes_under_pressure_home  \
# 0                                0.364780
# 1                                0.476190
# 2                                0.196491
# 3                                0.582857
# 4                                0.555556
# 5                                0.314516
# 6                                0.487500
# 7                                0.269565
# 8                                0.608000
# 9                                0.555556
# 10                               0.566372
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.000000
# 1                                            0.333333
# 2                                            0.400000
# 3                                            1.000000
# 4                                            0.750000
# 5                                            0.200000
# 6                                            1.000000
# 7                                            0.142857
# 8                                            0.666667
# 9                                            0.500000
# 10                                           0.000000
#
#     percentage_set_piece_shots_home  \
# 0                          0.214286
# 1                          0.470588
# 2                          0.333333
# 3                          0.600000
# 4                          0.615385
# 5                          0.200000
# 6                          0.533333
# 7                          0.642857
# 8                          0.818182
# 9                          0.428571
# 10                         0.538462
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.285714
# 1                                      0.000000
# 2                                      0.250000
# 3                                      0.444444
# 4                                      0.384615
# 5                                      0.250000
# 6                                      0.333333
# 7                                      0.400000
# 8                                      0.692308
# 9                                      0.166667
# 10                                     0.777778
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                    0.40
# 1                             0.5                                    0.50
# 2                             0.5                                    0.75
# 3                             0.5                                    0.60
# 4                             0.5                                    0.50
# 5                             0.5                                    0.50
# 6                             0.5                                    0.60
# 7                             0.5                                    0.60
# 8                             0.5                                    0.50
# 9                             0.4                                    0.40
# 10                            0.5                                    0.50
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           1.000000                           0.500000
# 1                           1.000000                           1.000000
# 2                           0.666667                           0.500000
# 3                           0.500000                           0.500000
# 4                           0.600000                           0.500000
# 5                           0.333333                           0.500000
# 6                           0.666667                           0.666667
# 7                           0.000000                           0.500000
# 8                           0.000000                           0.500000
# 9                           0.666667                           0.500000
# 10                          0.000000                           0.500000
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 20}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        21
#            1       0.67      0.56      0.61        18
#            2       0.72      0.78      0.75        37
#
#     accuracy                           0.70        76
#    macro avg       0.69      0.67      0.68        76
# weighted avg       0.70      0.70      0.69        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68        21
#            1       0.53      0.50      0.51        18
#            2       0.83      0.81      0.82        37
#
#     accuracy                           0.71        76
#    macro avg       0.67      0.68      0.67        76
# weighted avg       0.71      0.71      0.71        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'n_estimators': 15}
#               precision    recall  f1-score   support
#
#            0       0.58      0.67      0.62        21
#            1       0.67      0.44      0.53        18
#            2       0.78      0.84      0.81        37
#
#     accuracy                           0.70        76
#    macro avg       0.67      0.65      0.65        76
# weighted avg       0.70      0.70      0.69        76
#
# Random Forest MI
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 75}
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        21
#            1       0.43      0.33      0.38        18
#            2       0.73      0.81      0.77        37
#
#     accuracy                           0.64        76
#    macro avg       0.59      0.59      0.59        76
# weighted avg       0.63      0.64      0.63        76
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': None}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.46      0.57      0.51        21
#            1       0.40      0.22      0.29        18
#            2       0.65      0.70      0.68        37
#
#     accuracy                           0.55        76
#    macro avg       0.50      0.50      0.49        76
# weighted avg       0.54      0.55      0.54        76
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': None}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.50      0.38      0.43        21
#            1       0.31      0.50      0.38        18
#            2       0.81      0.68      0.74        37
#
#     accuracy                           0.55        76
#    macro avg       0.54      0.52      0.52        76
# weighted avg       0.60      0.55      0.57        76
#
# Decision Tree MI
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53        21
#            1       0.45      0.28      0.34        18
#            2       0.63      0.70      0.67        37
#
#     accuracy                           0.57        76
#    macro avg       0.53      0.52      0.51        76
# weighted avg       0.55      0.57      0.55        76
#
# Logistic Regression
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.74      0.67      0.70        21
#            1       0.45      0.50      0.47        18
#            2       0.81      0.81      0.81        37
#
#     accuracy                           0.70        76
#    macro avg       0.67      0.66      0.66        76
# weighted avg       0.70      0.70      0.70        76
#
# Logistic Regression Oversampling
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.62      0.67        21
#            1       0.41      0.50      0.45        18
#            2       0.81      0.78      0.79        37
#
#     accuracy                           0.67        76
#    macro avg       0.65      0.63      0.64        76
# weighted avg       0.69      0.67      0.68        76
#
# Logistic Regression MI
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'penalty': 'l1', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73        21
#            1       0.60      0.50      0.55        18
#            2       0.76      0.84      0.79        37
#
#     accuracy                           0.72        76
#    macro avg       0.70      0.68      0.69        76
# weighted avg       0.72      0.72      0.72        76
#
# Logistic Regression PCA
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.65      0.62      0.63        21
#            1       0.39      0.39      0.39        18
#            2       0.79      0.81      0.80        37
#
#     accuracy                           0.66        76
#    macro avg       0.61      0.61      0.61        76
# weighted avg       0.66      0.66      0.66        76
#
# KNN
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.56      0.43      0.49        21
#            1       0.33      0.28      0.30        18
#            2       0.73      0.89      0.80        37
#
#     accuracy                           0.62        76
#    macro avg       0.54      0.53      0.53        76
# weighted avg       0.59      0.62      0.60        76
#
# KNN Selected Features
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57        21
#            1       0.43      0.17      0.24        18
#            2       0.71      0.92      0.80        37
#
#     accuracy                           0.64        76
#    macro avg       0.57      0.55      0.54        76
# weighted avg       0.60      0.64      0.60        76
#
# KNN PCA
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 27, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.64      0.43      0.51        21
#            1       0.54      0.39      0.45        18
#            2       0.65      0.86      0.74        37
#
#     accuracy                           0.63        76
#    macro avg       0.61      0.56      0.57        76
# weighted avg       0.62      0.63      0.61        76
#
# Experiment finished.
#                                   Train Accuracy  Test Accuracy  \
# Random Forest                           0.881579       0.697368
# Random Forest Oversampling              0.988584       0.710526
# Random Forest Reduced                   0.947368       0.697368
# Random Forest MI                        0.828947       0.644737
# Decision Tree                           0.822368       0.552632
# Decision Tree Oversampling              0.885845       0.552632
# Decision Tree MI                        0.651316       0.565789
# Logistic Regression                     0.828947       0.697368
# Logistic Regression Oversampling        0.860731       0.671053
# Logistic Regression MI                  0.766447       0.723684
# Logistic Regression PCA                 0.766447       0.657895
# KNN                                     1.000000       0.618421
# KNN MI                                  1.000000       0.644737
# KNN PCA                                 1.000000       0.631579
#
#                                   Precision Macro  Precision Weighted  \
# Random Forest                            0.686111            0.695066
# Random Forest Oversampling               0.671640            0.711295
# Random Forest Reduced                    0.675000            0.696382
# Random Forest MI                         0.593109            0.628782
# Decision Tree                            0.503846            0.538715
# Decision Tree Oversampling               0.538932            0.604275
# Decision Tree MI                         0.529564            0.554543
# Logistic Regression                      0.665884            0.704917
# Logistic Regression Oversampling         0.645623            0.688630
# Logistic Regression MI                   0.702033            0.717442
# Logistic Regression PCA                  0.609454            0.656060
# KNN                                      0.543056            0.591393
# KNN MI                                   0.569444            0.604245
# KNN PCA                                  0.611460            0.623100
#
#                                   Recall Macro  Recall Weighted  F1 Macro  \
# Random Forest                         0.668669         0.697368  0.675325
# Random Forest Oversampling            0.675032         0.710526  0.672674
# Random Forest Reduced                 0.649650         0.697368  0.653583
# Random Forest MI                      0.587731         0.644737  0.587759
# Decision Tree                         0.498784         0.552632  0.490559
# Decision Tree Oversampling            0.518876         0.552632  0.516902
# Decision Tree MI                      0.517303         0.565789  0.514943
# Logistic Regression                   0.659159         0.697368  0.661498
# Logistic Regression Oversampling      0.634277         0.671053  0.637062
# Logistic Regression MI                0.684041         0.723684  0.690678
# Logistic Regression PCA               0.606249         0.657895  0.607678
# KNN                                   0.532747         0.618421  0.531465
# KNN MI                                0.552338         0.644737  0.537143
# KNN PCA                               0.560775         0.631579  0.570028
#
#                                   F1 Weighted  \
# Random Forest                        0.694463
# Random Forest Oversampling           0.710346
# Random Forest Reduced                0.690248
# Random Forest MI                     0.634362
# Decision Tree                        0.537543
# Decision Tree Oversampling           0.568166
# Decision Tree MI                     0.553600
# Logistic Regression                  0.700346
# Logistic Regression Oversampling     0.677596
# Logistic Regression MI               0.718346
# Logistic Regression PCA              0.656804
# KNN                                  0.598043
# KNN MI                               0.604211
# KNN PCA                              0.611367
#
#                                                              Hyperparameters chosen
# Random Forest                     {'criterion': 'entropy', 'max_depth': 4, 'max_...
# Random Forest Oversampling        {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Random Forest Reduced             {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Random Forest MI                  {'criterion': 'gini', 'max_depth': 3, 'max_fea...
# Decision Tree                     {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Decision Tree Oversampling        {'criterion': 'gini', 'max_depth': 6, 'max_fea...
# Decision Tree MI                  {'criterion': 'gini', 'max_depth': 2, 'max_fea...
# Logistic Regression               {'C': 0.3, 'l1_ratio': 0.5, 'penalty': 'elasti...
# Logistic Regression Oversampling  {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasti...
# Logistic Regression MI                {'C': 0.3, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression PCA           {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasti...
# KNN                               {'metric': 'manhattan', 'n_neighbors': 15, 'we...
# KNN MI                            {'metric': 'manhattan', 'n_neighbors': 11, 'we...
# KNN PCA                           {'metric': 'manhattan', 'n_neighbors': 27, 'we...

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "Premier League"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Premier League(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.111111                    0.555556
# 1                     0.300000                    0.285714
# 2                     0.260870                    0.500000
# 3                     0.421053                    0.555556
# 4                     0.454545                    0.454545
# 5                     0.352941                    0.636364
# 6                     0.166667                    0.428571
# 7                     0.166667                    0.375000
# 8                     0.400000                    0.625000
# 9                     0.222222                    0.350000
# 10                    0.235294                    0.454545
#
#     average_shots_on_target_distance_home  \
# 0                               15.620819
# 1                               10.397006
# 2                               15.724369
# 3                               16.690552
# 4                               18.363562
# 5                               19.786388
# 6                               13.669211
# 7                               31.108198
# 8                               21.126341
# 9                               19.430520
# 10                              23.333026
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               17.725682                      0.555556
# 1                               13.959668                      0.700000
# 2                               21.563397                      0.695652
# 3                               10.904830                      0.789474
# 4                               21.955396                      0.636364
# 5                               14.736918                      0.352941
# 6                               15.494298                      0.666667
# 7                               20.013645                      0.666667
# 8                               16.046596                      0.500000
# 9                               16.123497                      0.444444
# 10                              14.627453                      0.764706
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.777778                 0.808824
# 1                       0.714286                 0.773852
# 2                       0.500000                 0.834983
# 3                       0.666667                 0.711392
# 4                       0.363636                 0.785714
# 5                       0.727273                 0.794444
# 6                       0.571429                 0.829470
# 7                       0.500000                 0.729958
# 8                       0.750000                 0.768750
# 9                       0.550000                 0.768831
# 10                      0.727273                 0.798113
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.777778                  0.200000
# 1                  0.772834                  0.250000
# 2                  0.713158                  0.320000
# 3                  0.753012                  0.357143
# 4                  0.680912                  0.260870
# 5                  0.680380                  0.200000
# 6                  0.774713                  0.277778
# 7                  0.780534                  0.250000
# 8                  0.772124                  0.166667
# 9                  0.893484                  0.153846
# 10                 0.768018                  0.190476
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.285714  ...                              0.200000
# 1                   0.444444  ...                              0.250000
# 2                   0.166667  ...                              0.875000
# 3                   0.181818  ...                              0.625000
# 4                   0.200000  ...                              0.714286
# 5                   0.500000  ...                              0.333333
# 6                   0.100000  ...                              0.750000
# 7                   0.285714  ...                              0.500000
# 8                   0.250000  ...                              0.000000
# 9                   0.357143  ...                              0.285714
# 10                  0.444444  ...                              0.333333
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           0.000000
# 1                                           0.333333
# 2                                           0.875000
# 3                                           0.625000
# 4                                           0.800000
# 5                                           0.333333
# 6                                           0.750000
# 7                                           0.333333
# 8                                           0.000000
# 9                                           0.250000
# 10                                          0.500000
#
#     percentage_passes_under_pressure_home  \
# 0                                0.403846
# 1                                0.569620
# 2                                0.567797
# 3                                0.365672
# 4                                0.645833
# 5                                0.583333
# 6                                0.585185
# 7                                0.552326
# 8                                0.412844
# 9                                0.427632
# 10                               0.440367
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.285714
# 1                                            0.666667
# 2                                            0.750000
# 3                                            0.428571
# 4                                            0.600000
# 5                                            0.000000
# 6                                            1.000000
# 7                                            0.400000
# 8                                            0.333333
# 9                                            0.250000
# 10                                           0.666667
#
#     percentage_set_piece_shots_home  \
# 0                          0.400000
# 1                          0.533333
# 2                          0.642857
# 3                          0.647059
# 4                          0.615385
# 5                          0.647059
# 6                          0.666667
# 7                          0.500000
# 8                          0.294118
# 9                          0.318182
# 10                         0.529412
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.200000
# 1                                      0.500000
# 2                                      0.666667
# 3                                      0.666667
# 4                                      0.666667
# 5                                      0.500000
# 6                                      0.714286
# 7                                      0.500000
# 8                                      0.100000
# 9                                      0.250000
# 10                                     0.500000
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                     0.5
# 1                             0.6                                     0.5
# 2                             0.4                                     0.4
# 3                             0.6                                     0.6
# 4                             0.5                                     0.5
# 5                             0.5                                     0.5
# 6                             0.5                                     0.5
# 7                             0.6                                     0.6
# 8                             0.5                                     0.6
# 9                             0.5                                     0.5
# 10                            0.5                                     0.5
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                                0.5                                0.5
# 1                                0.5                                0.5
# 2                                1.0                                0.5
# 3                                0.5                                0.5
# 4                                0.5                                0.5
# 5                                0.5                                0.5
# 6                                0.0                                0.5
# 7                                0.5                                0.0
# 8                                1.0                                0.5
# 9                                1.0                                1.0
# 10                               1.0                                0.5
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.55      0.52      0.53        23
#            1       0.20      0.14      0.16        22
#            2       0.56      0.71      0.63        31
#
#     accuracy                           0.49        76
#    macro avg       0.44      0.46      0.44        76
# weighted avg       0.45      0.49      0.46        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.61      0.74      0.67        23
#            1       0.38      0.23      0.29        22
#            2       0.60      0.68      0.64        31
#
#     accuracy                           0.57        76
#    macro avg       0.53      0.55      0.53        76
# weighted avg       0.54      0.57      0.54        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 8, 'max_features': None, 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.50      0.74      0.60        23
#            1       0.27      0.14      0.18        22
#            2       0.74      0.74      0.74        31
#
#     accuracy                           0.57        76
#    macro avg       0.50      0.54      0.51        76
# weighted avg       0.53      0.57      0.54        76
#
# Random Forest MI
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 30}
#               precision    recall  f1-score   support
#
#            0       0.60      0.65      0.62        23
#            1       0.43      0.27      0.33        22
#            2       0.65      0.77      0.71        31
#
#     accuracy                           0.59        76
#    macro avg       0.56      0.57      0.55        76
# weighted avg       0.57      0.59      0.57        76
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 7, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.50      0.61      0.55        23
#            1       0.23      0.23      0.23        22
#            2       0.65      0.55      0.60        31
#
#     accuracy                           0.47        76
#    macro avg       0.46      0.46      0.46        76
# weighted avg       0.48      0.47      0.48        76
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.41      0.39      0.40        23
#            1       0.22      0.36      0.28        22
#            2       0.78      0.45      0.57        31
#
#     accuracy                           0.41        76
#    macro avg       0.47      0.40      0.42        76
# weighted avg       0.51      0.41      0.43        76
#
# Decision Tree MI
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2'}
#               precision    recall  f1-score   support
#
#            0       0.30      0.30      0.30        23
#            1       0.25      0.32      0.28        22
#            2       0.68      0.55      0.61        31
#
#     accuracy                           0.41        76
#    macro avg       0.41      0.39      0.40        76
# weighted avg       0.44      0.41      0.42        76
#
# Logistic Regression
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.59      0.57      0.58        23
#            1       0.53      0.41      0.46        22
#            2       0.68      0.81      0.74        31
#
#     accuracy                           0.62        76
#    macro avg       0.60      0.59      0.59        76
# weighted avg       0.61      0.62      0.61        76
#
# Logistic Regression Oversampling
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.4, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67        23
#            1       0.52      0.55      0.53        22
#            2       0.71      0.71      0.71        31
#
#     accuracy                           0.64        76
#    macro avg       0.64      0.64      0.64        76
# weighted avg       0.65      0.64      0.65        76
#
# Logistic Regression MI
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.5, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68        23
#            1       0.63      0.55      0.59        22
#            2       0.72      0.84      0.78        31
#
#     accuracy                           0.70        76
#    macro avg       0.69      0.68      0.68        76
# weighted avg       0.69      0.70      0.69        76
#
# Logistic Regression PCA
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# Best hyperparameters: {'C': 0.5, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.68      0.57      0.62        23
#            1       0.53      0.45      0.49        22
#            2       0.68      0.84      0.75        31
#
#     accuracy                           0.64        76
#    macro avg       0.63      0.62      0.62        76
# weighted avg       0.64      0.64      0.64        76
#
# KNN
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'metric': 'euclidean', 'n_neighbors': 25, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.42      0.43      0.43        23
#            1       0.42      0.23      0.29        22
#            2       0.60      0.77      0.68        31
#
#     accuracy                           0.51        76
#    macro avg       0.48      0.48      0.47        76
# weighted avg       0.49      0.51      0.49        76
#
# KNN Selected Features
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 17, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.41      0.39      0.40        23
#            1       0.24      0.18      0.21        22
#            2       0.59      0.71      0.65        31
#
#     accuracy                           0.46        76
#    macro avg       0.41      0.43      0.42        76
# weighted avg       0.43      0.46      0.44        76
#
# KNN PCA
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best hyperparameters: {'metric': 'euclidean', 'n_neighbors': 17, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.52      0.52        23
#            1       0.36      0.18      0.24        22
#            2       0.60      0.81      0.68        31
#
#     accuracy                           0.54        76
#    macro avg       0.49      0.50      0.48        76
# weighted avg       0.51      0.54      0.51        76
#
# Experiment finished.
#                                   Train Accuracy  Test Accuracy  \
# Random Forest                           0.980263       0.486842
# Random Forest Oversampling              0.978836       0.565789
# Random Forest Reduced                   1.000000       0.565789
# Random Forest MI                        0.980263       0.592105
# Decision Tree                           0.947368       0.473684
# Decision Tree Oversampling              0.917989       0.407895
# Decision Tree MI                        0.575658       0.407895
# Logistic Regression                     0.773026       0.618421
# Logistic Regression Oversampling        0.806878       0.644737
# Logistic Regression MI                  0.746711       0.697368
# Logistic Regression PCA                 0.733553       0.644737
# KNN                                     1.000000       0.513158
# KNN MI                                  1.000000       0.460526
# KNN PCA                                 1.000000       0.539474
#
#                                   Precision Macro  Precision Weighted  \
# Random Forest                            0.436519            0.453061
# Random Forest Oversampling               0.530586            0.539813
# Random Forest Reduced                    0.504888            0.532895
# Random Forest MI                         0.559073            0.570219
# Decision Tree                            0.460373            0.483806
# Decision Tree Oversampling               0.469697            0.505383
# Decision Tree MI                         0.411449            0.441842
# Logistic Regression                      0.598666            0.607683
# Logistic Regression Oversampling         0.637745            0.646843
# Logistic Regression MI                   0.689362            0.693582
# Logistic Regression PCA                  0.631579            0.638504
# KNN                                      0.477778            0.491447
# KNN MI                                   0.412993            0.434447
# KNN PCA                                  0.493538            0.505952
#
#                                   Recall Macro  Recall Weighted  F1 Macro  \
# Random Forest                         0.455927         0.486842  0.441356
# Random Forest Oversampling            0.547941         0.565789  0.529582
# Random Forest Reduced                 0.539143         0.565789  0.506748
# Random Forest MI                      0.566365         0.592105  0.554739
# Decision Tree                         0.461452         0.473684  0.457595
# Decision Tree Oversampling            0.402185         0.407895  0.415764
# Decision Tree MI                      0.390306         0.407895  0.397164
# Logistic Regression                   0.593587         0.618421  0.591537
# Logistic Regression Oversampling      0.635769         0.644737  0.636559
# Logistic Regression MI                0.678779         0.697368  0.681101
# Logistic Regression PCA               0.619491         0.644737  0.620159
# KNN                                   0.478750         0.513158  0.465235
# KNN MI                                0.427600         0.460526  0.417396
# KNN PCA                               0.503336         0.539474  0.483032
#
#                                   F1 Weighted  \
# Random Forest                        0.464736
# Random Forest Oversampling           0.544031
# Random Forest Reduced                0.535780
# Random Forest MI                     0.573562
# Decision Tree                        0.475246
# Decision Tree Oversampling           0.433990
# Decision Tree MI                     0.420808
# Logistic Regression                  0.608380
# Logistic Regression Oversampling     0.645614
# Logistic Regression MI               0.692363
# Logistic Regression PCA              0.635949
# KNN                                  0.489679
# KNN MI                               0.444364
# KNN PCA                              0.507450
#
#                                                              Hyperparameters chosen
# Random Forest                     {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Random Forest Oversampling        {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Random Forest Reduced             {'criterion': 'entropy', 'max_depth': 8, 'max_...
# Random Forest MI                  {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Decision Tree                     {'criterion': 'entropy', 'max_depth': 7, 'max_...
# Decision Tree Oversampling        {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Decision Tree MI                  {'criterion': 'gini', 'max_depth': 2, 'max_fea...
# Logistic Regression               {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasti...
# Logistic Regression Oversampling  {'C': 0.3, 'l1_ratio': 0.4, 'penalty': 'elasti...
# Logistic Regression MI            {'C': 0.5, 'l1_ratio': 0.5, 'penalty': 'elasti...
# Logistic Regression PCA           {'C': 0.5, 'l1_ratio': 0.6, 'penalty': 'elasti...
# KNN                               {'metric': 'euclidean', 'n_neighbors': 25, 'we...
# KNN MI                            {'metric': 'manhattan', 'n_neighbors': 17, 'we...
# KNN PCA                           {'metric': 'euclidean', 'n_neighbors': 17, 'we...

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "Serie A"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Serie A(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.285714                    0.285714
# 1                     0.583333                    0.285714
# 2                     0.250000                    0.250000
# 3                     0.230769                    0.230769
# 4                     0.352941                    0.266667
# 5                     0.700000                    0.280000
# 6                     0.315789                    0.300000
# 7                     0.363636                    0.000000
# 8                     0.500000                    0.000000
# 9                     0.409091                    0.444444
# 10                    0.388889                    0.200000
#
#     average_shots_on_target_distance_home  \
# 0                               16.182880
# 1                               16.798535
# 2                               17.663252
# 3                               25.183344
# 4                               14.242283
# 5                               15.873075
# 6                               16.958543
# 7                               25.565138
# 8                               22.505161
# 9                               22.443003
# 10                              21.034216
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               10.093019                      0.619048
# 1                               18.598700                      0.750000
# 2                               13.275137                      0.687500
# 3                               15.573483                      0.384615
# 4                               16.442821                      0.705882
# 5                               18.431269                      0.600000
# 6                               21.328243                      0.631579
# 7                              120.000000                      0.318182
# 8                              120.000000                      0.428571
# 9                               22.455211                      0.409091
# 10                               9.308799                      0.388889
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.857143                 0.795717
# 1                       0.523810                 0.656667
# 2                       0.750000                 0.792727
# 3                       0.538462                 0.741514
# 4                       0.666667                 0.707143
# 5                       0.520000                 0.847247
# 6                       0.400000                 0.757143
# 7                       0.800000                 0.856925
# 8                       0.555556                 0.825000
# 9                       0.555556                 0.821138
# 10                      0.600000                 0.832248
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.653614                  0.407407
# 1                  0.851100                  0.111111
# 2                  0.698824                  0.214286
# 3                  0.785714                  0.222222
# 4                  0.786885                  0.214286
# 5                  0.787724                  0.142857
# 6                  0.807910                  0.444444
# 7                  0.686901                  0.461538
# 8                  0.748792                  0.166667
# 9                  0.736264                  0.142857
# 10                 0.787634                  0.166667
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.500000  ...                              0.900000
# 1                   0.352941  ...                              0.500000
# 2                   0.250000  ...                              0.666667
# 3                   0.625000  ...                              0.285714
# 4                   0.222222  ...                              0.400000
# 5                   0.187500  ...                              0.153846
# 6                   0.214286  ...                              0.555556
# 7                   0.333333  ...                              0.857143
# 8                   0.307692  ...                              0.416667
# 9                   0.000000  ...                              0.444444
# 10                  0.142857  ...                              0.222222
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           0.888889
# 1                                           0.571429
# 2                                           0.800000
# 3                                           0.400000
# 4                                           0.444444
# 5                                           0.222222
# 6                                           0.714286
# 7                                           0.714286
# 8                                           0.333333
# 9                                           0.600000
# 10                                          0.166667
#
#     percentage_passes_under_pressure_home  \
# 0                                0.495238
# 1                                0.478992
# 2                                0.470588
# 3                                0.564885
# 4                                0.315476
# 5                                0.572581
# 6                                0.528455
# 7                                0.772727
# 8                                0.397727
# 9                                0.497382
# 10                               0.432692
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.750000
# 1                                            0.600000
# 2                                            0.333333
# 3                                            0.200000
# 4                                            0.333333
# 5                                            0.200000
# 6                                            0.750000
# 7                                            0.857143
# 8                                            0.571429
# 9                                            0.666667
# 10                                           1.000000
#
#     percentage_set_piece_shots_home  \
# 0                          0.750000
# 1                          0.315789
# 2                          0.588235
# 3                          0.280000
# 4                          0.631579
# 5                          0.347826
# 6                          0.687500
# 7                          0.923077
# 8                          0.500000
# 9                          0.636364
# 10                         0.590909
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.642857
# 1                                      0.312500
# 2                                      0.500000
# 3                                      0.307692
# 4                                      0.666667
# 5                                      0.285714
# 6                                      0.857143
# 7                                      0.800000
# 8                                      0.250000
# 9                                      0.583333
# 10                                     0.444444
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                     0.6
# 1                             0.5                                     0.4
# 2                             0.5                                     0.6
# 3                             0.5                                     0.5
# 4                             0.5                                     0.4
# 5                             0.4                                     0.4
# 6                             0.5                                     0.5
# 7                             0.5                                     0.5
# 8                             0.5                                     0.5
# 9                             0.5                                     0.5
# 10                            0.5                                     0.5
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           0.500000                                1.0
# 1                           0.500000                                0.5
# 2                           0.000000                                0.0
# 3                           1.000000                                1.0
# 4                           0.500000                                0.5
# 5                           0.500000                                0.5
# 6                           0.333333                                1.0
# 7                           0.600000                                0.5
# 8                           0.500000                                0.5
# 9                           0.800000                                0.5
# 10                          0.000000                                0.5
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        22
#            1       0.36      0.21      0.27        19
#            2       0.63      0.77      0.69        35
#
#     accuracy                           0.59        76
#    macro avg       0.54      0.54      0.53        76
# weighted avg       0.56      0.59      0.57        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65        22
#            1       0.33      0.26      0.29        19
#            2       0.67      0.83      0.74        35
#
#     accuracy                           0.62        76
#    macro avg       0.58      0.56      0.56        76
# weighted avg       0.60      0.62      0.60        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        22
#            1       0.33      0.16      0.21        19
#            2       0.63      0.77      0.69        35
#
#     accuracy                           0.58        76
#    macro avg       0.51      0.52      0.51        76
# weighted avg       0.54      0.58      0.55        76
#
# Random Forest MI
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        22
#            1       0.33      0.26      0.29        19
#            2       0.63      0.63      0.63        35
#
#     accuracy                           0.57        76
#    macro avg       0.53      0.54      0.53        76
# weighted avg       0.55      0.57      0.56        76
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        22
#            1       0.21      0.21      0.21        19
#            2       0.63      0.63      0.63        35
#
#     accuracy                           0.50        76
#    macro avg       0.46      0.46      0.46        76
# weighted avg       0.50      0.50      0.50        76
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        22
#            1       0.31      0.26      0.29        19
#            2       0.59      0.57      0.58        35
#
#     accuracy                           0.54        76
#    macro avg       0.51      0.52      0.51        76
# weighted avg       0.53      0.54      0.53        76
#
# Decision Tree MI
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.57      0.59      0.58        22
#            1       0.40      0.11      0.17        19
#            2       0.60      0.83      0.70        35
#
#     accuracy                           0.58        76
#    macro avg       0.52      0.51      0.48        76
# weighted avg       0.54      0.58      0.53        76
#
# Logistic Regression
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best hyperparameters: {'C': 1.5, 'penalty': 'l1', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        22
#            1       0.35      0.37      0.36        19
#            2       0.71      0.69      0.70        35
#
#     accuracy                           0.59        76
#    macro avg       0.56      0.56      0.56        76
# weighted avg       0.60      0.59      0.59        76
#
# Logistic Regression Oversampling
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'C': 0.75, 'penalty': 'l1', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.71      0.55      0.62        22
#            1       0.30      0.42      0.35        19
#            2       0.72      0.66      0.69        35
#
#     accuracy                           0.57        76
#    macro avg       0.57      0.54      0.55        76
# weighted avg       0.61      0.57      0.58        76
#
# Logistic Regression MI
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.25, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62        22
#            1       0.30      0.32      0.31        19
#            2       0.75      0.77      0.76        35
#
#     accuracy                           0.61        76
#    macro avg       0.57      0.56      0.56        76
# weighted avg       0.61      0.61      0.61        76
#
# Logistic Regression PCA
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# Best hyperparameters: {'C': 0.5, 'penalty': 'l2', 'solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.59        22
#            1       0.29      0.32      0.30        19
#            2       0.69      0.71      0.70        35
#
#     accuracy                           0.57        76
#    macro avg       0.54      0.53      0.53        76
# weighted avg       0.57      0.57      0.57        76
#
# KNN
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best hyperparameters: {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50        22
#            1       0.43      0.16      0.23        19
#            2       0.55      0.86      0.67        35
#
#     accuracy                           0.55        76
#    macro avg       0.54      0.47      0.47        76
# weighted avg       0.54      0.55      0.51        76
#
# KNN Selected Features
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52        22
#            1       0.33      0.21      0.26        19
#            2       0.66      0.83      0.73        35
#
#     accuracy                           0.58        76
#    macro avg       0.51      0.51      0.51        76
# weighted avg       0.55      0.58      0.55        76
#
# KNN PCA
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best hyperparameters: {'metric': 'euclidean', 'n_neighbors': 17, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.62      0.45      0.53        22
#            1       0.33      0.16      0.21        19
#            2       0.55      0.80      0.65        35
#
#     accuracy                           0.54        76
#    macro avg       0.50      0.47      0.46        76
# weighted avg       0.52      0.54      0.51        76
#
# Experiment finished.
#                                   Train Accuracy  Test Accuracy  \
# Random Forest                           0.970395       0.592105
# Random Forest Oversampling              0.971429       0.618421
# Random Forest Reduced                   0.976974       0.578947
# Random Forest MI                        0.819079       0.565789
# Decision Tree                           0.842105       0.500000
# Decision Tree Oversampling              0.919048       0.539474
# Decision Tree MI                        0.601974       0.578947
# Logistic Regression                     0.848684       0.592105
# Logistic Regression Oversampling        0.883333       0.565789
# Logistic Regression MI                  0.773026       0.605263
# Logistic Regression PCA                 0.773026       0.565789
# KNN                                     1.000000       0.552632
# KNN MI                                  1.000000       0.578947
# KNN PCA                                 1.000000       0.539474
#
#                                   Precision Macro  Precision Weighted  \
# Random Forest                            0.542636            0.564287
# Random Forest Oversampling               0.576658            0.602985
# Random Forest Reduced                    0.514858            0.541361
# Random Forest MI                         0.525763            0.550945
# Decision Tree                            0.461517            0.500000
# Decision Tree Oversampling               0.505373            0.527160
# Decision Tree MI                         0.523128            0.541850
# Logistic Regression                      0.564082            0.596788
# Logistic Regression Oversampling         0.573643            0.609412
# Logistic Regression MI                   0.566667            0.608553
# Logistic Regression PCA                  0.537246            0.574064
# KNN                                      0.538961            0.544429
# KNN MI                                   0.514141            0.546073
# KNN PCA                                  0.502451            0.517092
#
#                                   Recall Macro  Recall Weighted  F1 Macro  \
# Random Forest                         0.539440         0.592105  0.531779
# Random Forest Oversampling            0.560879         0.618421  0.562569
# Random Forest Reduced                 0.521896         0.578947  0.505096
# Random Forest MI                      0.539667         0.565789  0.529785
# Decision Tree                         0.461517         0.500000  0.461517
# Decision Tree Oversampling            0.520620         0.539474  0.510697
# Decision Tree MI                      0.508248         0.578947  0.481080
# Logistic Regression                   0.563500         0.592105  0.563663
# Logistic Regression Oversampling      0.541217         0.565789  0.549926
# Logistic Regression MI                0.559376         0.605263  0.562434
# Logistic Regression PCA               0.525177         0.565789  0.529864
# KNN                                   0.474710         0.552632  0.465812
# KNN MI                                0.513033         0.578947  0.505350
# KNN PCA                               0.470813         0.539474  0.463921
#
#                                   F1 Weighted  \
# Random Forest                        0.569703
# Random Forest Oversampling           0.604130
# Random Forest Reduced                0.548599
# Random Forest MI                     0.555986
# Decision Tree                        0.500000
# Decision Tree Oversampling           0.531383
# Decision Tree MI                     0.530732
# Logistic Regression                  0.594320
# Logistic Regression Oversampling     0.581276
# Logistic Regression MI               0.606381
# Logistic Regression PCA              0.568762
# KNN                                  0.509447
# KNN MI                               0.554253
# KNN PCA                              0.505804
#
#                                                              Hyperparameters chosen
# Random Forest                     {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Random Forest Oversampling        {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Random Forest Reduced             {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Random Forest MI                  {'criterion': 'gini', 'max_depth': 3, 'max_fea...
# Decision Tree                     {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Decision Tree Oversampling        {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Decision Tree MI                  {'criterion': 'gini', 'max_depth': 2, 'max_fea...
# Logistic Regression                   {'C': 1.5, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression Oversampling     {'C': 0.75, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression MI            {'C': 0.25, 'l1_ratio': 0.6, 'penalty': 'elast...
# Logistic Regression PCA              {'C': 0.5, 'penalty': 'l2', 'solver': 'lbfgs'}
# KNN                               {'metric': 'euclidean', 'n_neighbors': 20, 'we...
# KNN MI                            {'metric': 'manhattan', 'n_neighbors': 9, 'wei...
# KNN PCA                           {'metric': 'euclidean', 'n_neighbors': 17, 'we...

# %%
import pandas as pd
import os


competition_name = "Ligue 1"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/Ligue 1(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.333333                    0.166667
# 1                     0.307692                    0.428571
# 2                     0.166667                    0.333333
# 3                     0.333333                    0.352941
# 4                     0.227273                    0.500000
# 5                     0.363636                    0.312500
# 6                     0.400000                    0.400000
# 7                     0.307692                    0.142857
# 8                     0.272727                    0.500000
# 9                     0.222222                    0.500000
# 10                    0.312500                    0.285714
#
#     average_shots_on_target_distance_home  \
# 0                               25.129294
# 1                               20.107446
# 2                               21.737917
# 3                               12.209684
# 4                               20.112628
# 5                               19.214504
# 6                               24.601604
# 7                               18.537424
# 8                               10.795861
# 9                               16.667752
# 10                              19.338557
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               12.803802                      0.555556
# 1                               19.128651                      0.230769
# 2                               19.467647                      0.333333
# 3                               15.420536                      0.666667
# 4                               20.723704                      0.500000
# 5                               14.360387                      0.727273
# 6                               21.199364                      0.200000
# 7                               33.354160                      0.461538
# 8                               13.757933                      0.545455
# 9                               18.455527                      0.666667
# 10                              20.924156                      0.500000
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.583333                 0.763676
# 1                       0.714286                 0.747412
# 2                       0.833333                 0.798755
# 3                       0.764706                 0.741688
# 4                       0.500000                 0.876560
# 5                       0.812500                 0.811419
# 6                       0.500000                 0.775472
# 7                       0.571429                 0.764151
# 8                       0.333333                 0.712264
# 9                       0.625000                 0.791667
# 10                      0.428571                 0.724234
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.809074                  0.307692
# 1                  0.783058                  0.500000
# 2                  0.829213                  0.200000
# 3                  0.810964                  0.250000
# 4                  0.786082                  0.142857
# 5                  0.705202                  0.500000
# 6                  0.754258                  0.363636
# 7                  0.770241                  0.050000
# 8                  0.745995                  0.294118
# 9                  0.565693                  0.200000
# 10                 0.774074                  0.250000
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.571429  ...                              0.333333
# 1                   0.250000  ...                              0.375000
# 2                   0.333333  ...                              0.000000
# 3                   0.454545  ...                              0.250000
# 4                   1.000000  ...                              0.444444
# 5                   0.833333  ...                              0.363636
# 6                   0.111111  ...                              0.400000
# 7                   0.076923  ...                              0.750000
# 8                   0.333333  ...                              0.714286
# 9                   0.090909  ...                              0.500000
# 10                  0.250000  ...                              0.615385
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           0.333333
# 1                                           0.166667
# 2                                           0.000000
# 3                                           0.285714
# 4                                           0.600000
# 5                                           0.375000
# 6                                           0.166667
# 7                                           1.000000
# 8                                           1.000000
# 9                                           0.600000
# 10                                          0.666667
#
#     percentage_passes_under_pressure_home  \
# 0                                0.566265
# 1                                0.565217
# 2                                0.520000
# 3                                0.514085
# 4                                0.684564
# 5                                0.666667
# 6                                0.597826
# 7                                0.596154
# 8                                0.469512
# 9                                0.641379
# 10                               0.591623
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            1.000000
# 1                                            0.500000
# 2                                            0.000000
# 3                                            0.000000
# 4                                            1.000000
# 5                                            0.500000
# 6                                            0.625000
# 7                                            0.600000
# 8                                            0.600000
# 9                                            0.600000
# 10                                           0.333333
#
#     percentage_set_piece_shots_home  \
# 0                          0.555556
# 1                          0.500000
# 2                          0.666667
# 3                          0.384615
# 4                          0.875000
# 5                          0.470588
# 6                          0.583333
# 7                          0.666667
# 8                          0.714286
# 9                          0.714286
# 10                         0.550000
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.666667
# 1                                      0.222222
# 2                                      0.500000
# 3                                      0.333333
# 4                                      0.875000
# 5                                      0.428571
# 6                                      0.250000
# 7                                      0.666667
# 8                                      0.800000
# 9                                      0.777778
# 10                                     0.444444
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                    0.50
# 1                             0.5                                    0.40
# 2                             0.5                                    0.50
# 3                             0.5                                    0.25
# 4                             0.5                                    0.50
# 5                             0.6                                    0.60
# 6                             0.5                                    0.50
# 7                             0.6                                    0.60
# 8                             0.5                                    0.60
# 9                             0.5                                    0.50
# 10                            0.5                                    0.50
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           0.750000                           0.666667
# 1                           0.444444                           0.750000
# 2                           0.500000                           0.000000
# 3                           0.625000                           1.000000
# 4                           0.500000                           0.500000
# 5                           0.750000                           1.000000
# 6                           0.500000                           0.500000
# 7                           1.000000                           0.500000
# 8                           0.666667                           1.000000
# 9                           0.666667                           0.500000
# 10                          0.666667                           0.500000
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        22
#            1       0.37      0.32      0.34        22
#            2       0.64      0.78      0.70        32
#
#     accuracy                           0.58        76
#    macro avg       0.56      0.55      0.55        76
# weighted avg       0.57      0.58      0.57        76
#
# Random Forest Oversampling
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 60}
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65        22
#            1       0.33      0.27      0.30        22
#            2       0.60      0.75      0.67        32
#
#     accuracy                           0.57        76
#    macro avg       0.55      0.54      0.54        76
# weighted avg       0.56      0.57      0.56        76
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.59        22
#            1       0.42      0.36      0.39        22
#            2       0.63      0.75      0.69        32
#
#     accuracy                           0.58        76
#    macro avg       0.56      0.55      0.55        76
# weighted avg       0.57      0.58      0.57        76
#
# Random Forest MI
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 30}
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59        22
#            1       0.36      0.23      0.28        22
#            2       0.65      0.81      0.72        32
#
#     accuracy                           0.58        76
#    macro avg       0.53      0.54      0.53        76
# weighted avg       0.55      0.58      0.56        76
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 12, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.64      0.32      0.42        22
#            1       0.33      0.36      0.35        22
#            2       0.59      0.75      0.66        32
#
#     accuracy                           0.51        76
#    macro avg       0.52      0.48      0.48        76
# weighted avg       0.53      0.51      0.50        76
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2'}
#               precision    recall  f1-score   support
#
#            0       0.23      0.32      0.27        22
#            1       0.41      0.32      0.36        22
#            2       0.41      0.38      0.39        32
#
#     accuracy                           0.34        76
#    macro avg       0.35      0.34      0.34        76
# weighted avg       0.36      0.34      0.35        76
#
# Decision Tree MI
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.89      0.36      0.52        22
#            1       0.35      0.64      0.45        22
#            2       0.67      0.56      0.61        32
#
#     accuracy                           0.53        76
#    macro avg       0.64      0.52      0.53        76
# weighted avg       0.64      0.53      0.54        76
#
# Logistic Regression
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.76      0.59      0.67        22
#            1       0.40      0.36      0.38        22
#            2       0.56      0.69      0.62        32
#
#     accuracy                           0.57        76
#    macro avg       0.58      0.55      0.56        76
# weighted avg       0.57      0.57      0.56        76
#
# Logistic Regression Oversampling
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'C': 0.75, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.76      0.59      0.67        22
#            1       0.45      0.45      0.45        22
#            2       0.62      0.72      0.67        32
#
#     accuracy                           0.61        76
#    macro avg       0.61      0.59      0.60        76
# weighted avg       0.61      0.61      0.61        76
#
# Logistic Regression MI
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.5, 'penalty': 'l1', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.75      0.55      0.63        22
#            1       0.29      0.23      0.26        22
#            2       0.58      0.78      0.67        32
#
#     accuracy                           0.55        76
#    macro avg       0.54      0.52      0.52        76
# weighted avg       0.55      0.55      0.54        76
#
# Logistic Regression PCA
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# Best hyperparameters: {'C': 0.2, 'penalty': 'l2', 'solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.69      0.50      0.58        22
#            1       0.41      0.41      0.41        22
#            2       0.55      0.66      0.60        32
#
#     accuracy                           0.54        76
#    macro avg       0.55      0.52      0.53        76
# weighted avg       0.55      0.54      0.54        76
#
# KNN
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.50      0.23      0.31        22
#            1       0.57      0.18      0.28        22
#            2       0.46      0.84      0.59        32
#
#     accuracy                           0.47        76
#    macro avg       0.51      0.42      0.39        76
# weighted avg       0.50      0.47      0.42        76
#
# KNN Selected Features
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.36      0.44        22
#            1       0.39      0.32      0.35        22
#            2       0.55      0.75      0.63        32
#
#     accuracy                           0.51        76
#    macro avg       0.50      0.48      0.48        76
# weighted avg       0.51      0.51      0.50        76
#
# KNN PCA
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.62      0.36      0.46        22
#            1       0.42      0.23      0.29        22
#            2       0.53      0.84      0.65        32
#
#     accuracy                           0.53        76
#    macro avg       0.52      0.48      0.47        76
# weighted avg       0.52      0.53      0.49        76
#
# Experiment finished.
#                                   Train Accuracy  Test Accuracy  \
# Random Forest                           0.840532       0.578947
# Random Forest Oversampling              0.997396       0.565789
# Random Forest Reduced                   0.996678       0.578947
# Random Forest MI                        0.953488       0.578947
# Decision Tree                           1.000000       0.513158
# Decision Tree Oversampling              0.736979       0.342105
# Decision Tree MI                        0.734219       0.526316
# Logistic Regression                     0.770764       0.565789
# Logistic Regression Oversampling        0.815104       0.605263
# Logistic Regression MI                  0.720930       0.552632
# Logistic Regression PCA                 0.730897       0.539474
# KNN                                     1.000000       0.473684
# KNN MI                                  1.000000       0.513158
# KNN PCA                                 1.000000       0.526316
#
#                                   Precision Macro  Precision Weighted  \
# Random Forest                            0.558704            0.569536
# Random Forest Oversampling               0.551852            0.558187
# Random Forest Reduced                    0.561404            0.570637
# Random Forest MI                         0.532684            0.548120
# Decision Tree                            0.518354            0.527172
# Decision Tree Oversampling               0.352964            0.360968
# Decision Tree MI                         0.635185            0.639327
# Logistic Regression                      0.576269            0.574669
# Logistic Regression Oversampling         0.613624            0.614677
# Logistic Regression MI                   0.541838            0.547043
# Logistic Regression PCA                  0.549741            0.550121
# KNN                                      0.509685            0.502835
# KNN MI                                   0.501924            0.507652
# KNN PCA                                  0.520488            0.521662
#
#                                   Recall Macro  Recall Weighted  F1 Macro  \
# Random Forest                         0.548295         0.578947  0.548563
# Random Forest Oversampling            0.537879         0.565789  0.538889
# Random Forest Reduced                 0.553030         0.578947  0.553775
# Random Forest MI                      0.543561         0.578947  0.530303
# Decision Tree                         0.477273         0.513158  0.476534
# Decision Tree Oversampling            0.337121         0.342105  0.340549
# Decision Tree MI                      0.520833         0.526316  0.525970
# Logistic Regression                   0.547348         0.565789  0.555779
# Logistic Regression Oversampling      0.588068         0.605263  0.595960
# Logistic Regression MI                0.517992         0.552632  0.518219
# Logistic Regression PCA               0.521780         0.539474  0.529346
# KNN                                   0.417614         0.473684  0.393923
# KNN MI                                0.477273         0.513158  0.475341
# KNN PCA                               0.478220         0.526316  0.467288
#
#                                   F1 Weighted  \
# Random Forest                        0.569045
# Random Forest Oversampling           0.555702
# Random Forest Reduced                0.571135
# Random Forest MI                     0.555556
# Decision Tree                        0.500350
# Decision Tree Oversampling           0.347509
# Decision Tree MI                     0.537049
# Logistic Regression                  0.564192
# Logistic Regression Oversampling     0.605263
# Logistic Regression MI               0.537751
# Logistic Regression PCA              0.538643
# KNN                                  0.420171
# KNN MI                               0.495899
# KNN PCA                              0.491408
#
#                                                              Hyperparameters chosen
# Random Forest                     {'criterion': 'entropy', 'max_depth': 3, 'max_...
# Random Forest Oversampling        {'criterion': 'gini', 'max_depth': 6, 'max_fea...
# Random Forest Reduced             {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Random Forest MI                  {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Decision Tree                     {'criterion': 'gini', 'max_depth': 12, 'max_fe...
# Decision Tree Oversampling        {'criterion': 'gini', 'max_depth': 6, 'max_fea...
# Decision Tree MI                  {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Logistic Regression               {'C': 0.3, 'l1_ratio': 0.5, 'penalty': 'elasti...
# Logistic Regression Oversampling  {'C': 0.75, 'l1_ratio': 0.5, 'penalty': 'elast...
# Logistic Regression MI                {'C': 0.5, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression PCA              {'C': 0.2, 'penalty': 'l2', 'solver': 'lbfgs'}
# KNN                               {'metric': 'manhattan', 'n_neighbors': 15, 'we...
# KNN MI                            {'metric': 'manhattan', 'n_neighbors': 5, 'wei...
# KNN PCA                           {'metric': 'manhattan', 'n_neighbors': 15, 'we...

# %% [markdown]
# Seleccionamos la competición con la que queremos experimentar.

# %%
import pandas as pd
import os


competition_name = "1. Bundesliga"
competition_gender = "male"
season_name_for_filename = "2015_2016"

output_dir = "data/reduced/"
filename = f"{competition_name}({season_name_for_filename}_{competition_gender})_reduced.csv"
output_path = os.path.join(output_dir, filename)

if os.path.exists(output_path):
    print(f"Matches from the competition loaded from {output_path}")
    matches_in_competition_season = pd.read_csv(output_path)
else:
    print("You don't have data from the competition yet. Please run the notebook '0_datasets_building.ipynb' first.")
# Out:
# Matches from the competition loaded from data/reduced/1. Bundesliga(2015_2016_male)_reduced.csv

# %%
matches_in_competition_season.head(11)
# Out:
#     shots_on_target_ratio_home  shots_on_target_ratio_away  \
# 0                     0.375000                    0.461538
# 1                     0.150000                    0.272727
# 2                     0.133333                    0.312500
# 3                     0.272727                    0.357143
# 4                     0.272727                    0.357143
# 5                     0.360000                    0.333333
# 6                     0.285714                    0.500000
# 7                     0.437500                    0.200000
# 8                     0.409091                    0.200000
# 9                     0.666667                    0.444444
# 10                    0.555556                    0.400000
#
#     average_shots_on_target_distance_home  \
# 0                               16.622853
# 1                               20.255117
# 2                               26.271612
# 3                               18.619963
# 4                               20.860604
# 5                               15.171696
# 6                               16.794278
# 7                               18.087399
# 8                               19.197658
# 9                               22.303827
# 10                              13.788140
#
#     average_shots_on_target_distance_away  shots_inside_area_ratio_home  \
# 0                               13.820947                      0.750000
# 1                               17.607160                      0.500000
# 2                               17.542449                      0.333333
# 3                               21.381858                      0.454545
# 4                               15.628223                      0.818182
# 5                               20.848069                      0.800000
# 6                               14.812360                      0.607143
# 7                               12.414910                      0.562500
# 8                               18.990787                      0.590909
# 9                               15.568264                      0.666667
# 10                              18.718023                      0.888889
#
#     shots_inside_area_ratio_away  pass_success_ratio_home  \
# 0                       0.692308                 0.832013
# 1                       0.545455                 0.772727
# 2                       0.500000                 0.767241
# 3                       0.428571                 0.688000
# 4                       0.428571                 0.490909
# 5                       0.666667                 0.705376
# 6                       0.500000                 0.724670
# 7                       0.600000                 0.872777
# 8                       0.400000                 0.892095
# 9                       0.888889                 0.567485
# 10                      0.666667                 0.663366
#
#     pass_success_ratio_away  cross_success_ratio_home  \
# 0                  0.755051                  0.250000
# 1                  0.828261                  0.318182
# 2                  0.704301                  0.200000
# 3                  0.620690                  0.214286
# 4                  0.657431                  0.300000
# 5                  0.592145                  0.333333
# 6                  0.658120                  0.310345
# 7                  0.795031                  0.300000
# 8                  0.625000                  0.470588
# 9                  0.774878                  0.333333
# 10                 0.823088                  0.500000
#
#     cross_success_ratio_away  ...  percentage_shots_under_pressure_home  \
# 0                   0.500000  ...                              0.250000
# 1                   0.444444  ...                              0.769231
# 2                   0.333333  ...                              0.500000
# 3                   0.200000  ...                              0.444444
# 4                   0.142857  ...                              0.222222
# 5                   0.222222  ...                              0.857143
# 6                   0.111111  ...                              0.818182
# 7                   0.000000  ...                              0.714286
# 8                   0.500000  ...                              0.777778
# 9                   0.400000  ...                              0.250000
# 10                  0.192308  ...                              0.375000
#
#     percentage_shots_inside_area_under_pressure_home  \
# 0                                           0.400000
# 1                                           0.750000
# 2                                           0.400000
# 3                                           0.571429
# 4                                           0.250000
# 5                                           0.833333
# 6                                           1.000000
# 7                                           0.666667
# 8                                           0.857143
# 9                                           0.142857
# 10                                          0.428571
#
#     percentage_passes_under_pressure_home  \
# 0                                0.574713
# 1                                0.441718
# 2                                0.595376
# 3                                0.502924
# 4                                0.375000
# 5                                0.545455
# 6                                0.385870
# 7                                0.620482
# 8                                0.780899
# 9                                0.496815
# 10                               0.434109
#
#     percentage_passes_inside_area_under_pressure_home  \
# 0                                            0.500000
# 1                                            0.750000
# 2                                            1.000000
# 3                                            0.500000
# 4                                            0.600000
# 5                                            0.375000
# 6                                            0.750000
# 7                                            0.750000
# 8                                            1.000000
# 9                                            0.666667
# 10                                           0.600000
#
#     percentage_set_piece_shots_home  \
# 0                          0.266667
# 1                          0.680000
# 2                          0.476190
# 3                          0.458333
# 4                          0.400000
# 5                          0.809524
# 6                          0.812500
# 7                          0.636364
# 8                          0.842105
# 9                          0.153846
# 10                         0.272727
#
#     percentage_set_piece_shots_inside_area_home  \
# 0                                      0.300000
# 1                                      0.727273
# 2                                      0.500000
# 3                                      0.454545
# 4                                      0.600000
# 5                                      0.857143
# 6                                      0.875000
# 7                                      0.571429
# 8                                      0.900000
# 9                                      0.090909
# 10                                     0.333333
#
#     percentage_substitutions_home  percentage_tactical_substitutions_home  \
# 0                             0.5                                    0.50
# 1                             0.5                                    0.50
# 2                             0.5                                    0.60
# 3                             0.5                                    0.50
# 4                             0.5                                    0.50
# 5                             0.5                                    0.50
# 6                             0.5                                    0.50
# 7                             0.5                                    0.50
# 8                             0.5                                    0.50
# 9                             0.5                                    0.25
# 10                            0.4                                    0.40
#
#     percentage_tactical_changes_home  percentage_formation_changes_home
# 0                           0.500000                           0.000000
# 1                           0.500000                           0.666667
# 2                           0.333333                           0.500000
# 3                           1.000000                           1.000000
# 4                           0.200000                           0.000000
# 5                           0.500000                           1.000000
# 6                           0.333333                           0.500000
# 7                           1.000000                           1.000000
# 8                           0.500000                           0.000000
# 9                           0.666667                           0.500000
# 10                          0.166667                           0.333333
#
# [11 rows x 89 columns]

# %%
from src.experimentation import ExperimentLauncher

experiment_launcher = ExperimentLauncher(matches_in_competition_season)
experiment_launcher.run()
# Out:
# Starting experiment...
# Random Forest
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65        20
#            1       0.33      0.13      0.19        15
#            2       0.61      0.81      0.70        27
#
#     accuracy                           0.60        62
#    macro avg       0.53      0.53      0.51        62
# weighted avg       0.56      0.60      0.56        62
#
# Random Forest Oversampling
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.56      0.45      0.50        20
#            1       0.29      0.27      0.28        15
#            2       0.66      0.78      0.71        27
#
#     accuracy                           0.55        62
#    macro avg       0.50      0.50      0.50        62
# weighted avg       0.54      0.55      0.54        62
#
# Random Forest Selected Features
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 40}
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        20
#            1       0.25      0.07      0.11        15
#            2       0.65      0.81      0.72        27
#
#     accuracy                           0.60        62
#    macro avg       0.49      0.53      0.49        62
# weighted avg       0.53      0.60      0.54        62
#
# Random Forest MI
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56        20
#            1       0.33      0.13      0.19        15
#            2       0.73      0.89      0.80        27
#
#     accuracy                           0.61        62
#    macro avg       0.53      0.54      0.52        62
# weighted avg       0.57      0.61      0.57        62
#
# Decision Tree
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 12, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.53      0.40      0.46        20
#            1       0.33      0.33      0.33        15
#            2       0.56      0.67      0.61        27
#
#     accuracy                           0.50        62
#    macro avg       0.48      0.47      0.47        62
# weighted avg       0.50      0.50      0.49        62
#
# Decision Tree Oversampling
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        20
#            1       0.22      0.33      0.26        15
#            2       0.65      0.41      0.50        27
#
#     accuracy                           0.44        62
#    macro avg       0.45      0.43      0.43        62
# weighted avg       0.50      0.44      0.45        62
#
# Decision Tree MI
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 7, 'max_features': None}
#               precision    recall  f1-score   support
#
#            0       0.61      0.55      0.58        20
#            1       0.24      0.27      0.25        15
#            2       0.59      0.59      0.59        27
#
#     accuracy                           0.50        62
#    macro avg       0.48      0.47      0.47        62
# weighted avg       0.51      0.50      0.51        62
#
# Logistic Regression
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        20
#            1       0.43      0.20      0.27        15
#            2       0.66      0.85      0.74        27
#
#     accuracy                           0.61        62
#    macro avg       0.56      0.55      0.54        62
# weighted avg       0.58      0.61      0.58        62
#
# Logistic Regression Oversampling
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best hyperparameters: {'C': 1.5, 'penalty': 'l1', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62        20
#            1       0.50      0.27      0.35        15
#            2       0.66      0.78      0.71        27
#
#     accuracy                           0.61        62
#    macro avg       0.58      0.56      0.56        62
# weighted avg       0.60      0.61      0.59        62
#
# Logistic Regression MI
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# Best hyperparameters: {'C': 0.3, 'penalty': 'l2', 'solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.60      0.59        20
#            1       0.57      0.27      0.36        15
#            2       0.68      0.85      0.75        27
#
#     accuracy                           0.63        62
#    macro avg       0.61      0.57      0.57        62
# weighted avg       0.62      0.63      0.61        62
#
# Logistic Regression PCA
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# Best hyperparameters: {'C': 0.5, 'l1_ratio': 0.4, 'penalty': 'elasticnet', 'solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.61      0.70      0.65        20
#            1       0.33      0.20      0.25        15
#            2       0.67      0.74      0.70        27
#
#     accuracy                           0.60        62
#    macro avg       0.54      0.55      0.53        62
# weighted avg       0.57      0.60      0.58        62
#
# KNN
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# c:\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51        20
#            1       0.42      0.33      0.37        15
#            2       0.58      0.67      0.62        27
#
#     accuracy                           0.53        62
#    macro avg       0.51      0.50      0.50        62
# weighted avg       0.52      0.53      0.53        62
#
# KNN Selected Features
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        20
#            1       0.40      0.27      0.32        15
#            2       0.63      0.70      0.67        27
#
#     accuracy                           0.55        62
#    macro avg       0.51      0.51      0.50        62
# weighted avg       0.53      0.55      0.54        62
#
# KNN PCA
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        20
#            1       0.33      0.07      0.11        15
#            2       0.53      0.89      0.67        27
#
#     accuracy                           0.53        62
#    macro avg       0.48      0.45      0.42        62
# weighted avg       0.50      0.53      0.47        62
#
# Experiment finished.
#                                   Train Accuracy  Test Accuracy  \
# Random Forest                           0.979508       0.596774
# Random Forest Oversampling              0.996914       0.548387
# Random Forest Reduced                   0.995902       0.596774
# Random Forest MI                        0.922131       0.612903
# Decision Tree                           1.000000       0.500000
# Decision Tree Oversampling              0.814815       0.435484
# Decision Tree MI                        0.909836       0.500000
# Logistic Regression                     0.803279       0.612903
# Logistic Regression Oversampling        0.882716       0.612903
# Logistic Regression MI                  0.774590       0.629032
# Logistic Regression PCA                 0.754098       0.596774
# KNN                                     1.000000       0.532258
# KNN MI                                  1.000000       0.548387
# KNN PCA                                 1.000000       0.532258
#
#                                   Precision Macro  Precision Weighted  \
# Random Forest                            0.531481            0.556452
# Random Forest Oversampling               0.501488            0.536362
# Random Forest Reduced                    0.493464            0.530440
# Random Forest MI                         0.527448            0.565664
# Decision Tree                            0.476389            0.497648
# Decision Tree Oversampling               0.454817            0.495669
# Decision Tree MI                         0.479666            0.512123
# Logistic Regression                      0.561905            0.583410
# Logistic Regression Oversampling         0.582386            0.597370
# Logistic Regression MI                   0.606443            0.617173
# Logistic Regression PCA                  0.536232            0.567321
# KNN                                      0.507876            0.523447
# KNN MI                                   0.511111            0.533871
# KNN PCA                                  0.479365            0.497235
#
#                                   Recall Macro  Recall Weighted  F1 Macro  \
# Random Forest                         0.532716         0.596774  0.512963
# Random Forest Oversampling            0.498148         0.548387  0.495909
# Random Forest Reduced                 0.527160         0.596774  0.487646
# Random Forest MI                      0.540741         0.612903  0.516205
# Decision Tree                         0.466667         0.500000  0.466882
# Decision Tree Oversampling            0.430247         0.435484  0.428989
# Decision Tree MI                      0.469753         0.500000  0.473847
# Logistic Regression                   0.550617         0.612903  0.538221
# Logistic Regression Oversampling      0.564815         0.612903  0.559579
# Logistic Regression MI                0.572840         0.629032  0.567700
# Logistic Regression PCA               0.546914         0.596774  0.534306
# KNN                                   0.500000         0.532258  0.501294
# KNN MI                                0.506790         0.548387  0.503492
# KNN PCA                               0.451852         0.532258  0.416122
#
#                                   F1 Weighted  \
# Random Forest                        0.559908
# Random Forest Oversampling           0.538037
# Random Forest Reduced                0.544865
# Random Forest MI                     0.574515
# Decision Tree                        0.493830
# Decision Tree Oversampling           0.450380
# Decision Tree MI                     0.505306
# Logistic Regression                  0.582632
# Logistic Regression Oversampling     0.593850
# Logistic Regression MI               0.605202
# Logistic Regression PCA              0.576139
# KNN                                  0.525332
# KNN MI                               0.536713
# KNN PCA                              0.469007
#
#                                                              Hyperparameters chosen
# Random Forest                     {'criterion': 'gini', 'max_depth': 5, 'max_fea...
# Random Forest Oversampling        {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Random Forest Reduced             {'criterion': 'entropy', 'max_depth': 6, 'max_...
# Random Forest MI                  {'criterion': 'entropy', 'max_depth': 4, 'max_...
# Decision Tree                     {'criterion': 'gini', 'max_depth': 12, 'max_fe...
# Decision Tree Oversampling        {'criterion': 'entropy', 'max_depth': 5, 'max_...
# Decision Tree MI                  {'criterion': 'gini', 'max_depth': 7, 'max_fea...
# Logistic Regression               {'C': 0.3, 'l1_ratio': 0.6, 'penalty': 'elasti...
# Logistic Regression Oversampling      {'C': 1.5, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression MI               {'C': 0.3, 'penalty': 'l2', 'solver': 'lbfgs'}
# Logistic Regression PCA           {'C': 0.5, 'l1_ratio': 0.4, 'penalty': 'elasti...
# KNN                               {'metric': 'manhattan', 'n_neighbors': 5, 'wei...
# KNN MI                            {'metric': 'manhattan', 'n_neighbors': 9, 'wei...
# KNN PCA                           {'metric': 'manhattan', 'n_neighbors': 20, 'we...
